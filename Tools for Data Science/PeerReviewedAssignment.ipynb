# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Sudipto Ghosh**
#
# Undergraduate Student, University of Delhi

# %% [markdown]
# _I am interested in data science because analysis of data helps understand the vital statistics of the dataset._

# %% [markdown]
# ### Area of Unit Circle

# %%
1. * 1.
# Out:
# 1.0

# %% [markdown]
#   * Item 1
#   * Item 2
#   * Item 3
#
# ---
#
# [GitHub Profile](https://github.com/sudiptog81/)
#
# ```
# print('Hello, World')
# ```
